# %%
import pandas as pd
import numpy as np
import pylab as pl
from urllib.request import urlopen
import matplotlib.pylab as plt
import io
import zipfile
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %%
url ='http://databank.worldbank.org/data/download/INDODAPOER_csv.zip'

# %%
z = zipfile.ZipFile( 
        io.BytesIO( 
            urllib.urlopen(url).read() # Loads from url
        ) # Converts to bytes (from unicode) 
    ) # load zip file
print(z.namelist())
# Out:
# ['INDODAPOERData.csv', 'INDODAPOERSeries.csv']

# %%
filename = z.namelist()[0]
df = pd.read_csv(z.open(filename))

# %%
df.head()
# Out:
#   Country Name          Country Code  \
# 0  Ambon, Kota  IDN_Ambon_Kota_18139
# 1  Ambon, Kota  IDN_Ambon_Kota_18139
# 2  Ambon, Kota  IDN_Ambon_Kota_18139
# 3  Ambon, Kota  IDN_Ambon_Kota_18139
# 4  Ambon, Kota  IDN_Ambon_Kota_18139
#
#                                       Indicator Name     Indicator Code  1976  \
# 0          Agriculture function expenditure (in IDR)      FC.XPD.AGR.CR   NaN
# 1  Average National Exam Score: Junior Secondary ...  SE.NEXM.SCR.JRSEC   NaN
# 2  Average National Exam Score: Primary Level (ou...    SE.NEXM.SCR.PRM   NaN
# 3  Average National Exam Score: Senior Secondary ...  SE.NEXM.SCR.SRSEC   NaN
# 4  Birth attended by Skilled Health worker (in % ...     SH.STA.BRTC.ZS   NaN
#
#    1977  1978  1979  1980  1981     ...               2006          2007  \
# 0   NaN   NaN   NaN   NaN   NaN     ...       1.200477e+10  1.682838e+10
# 1   NaN   NaN   NaN   NaN   NaN     ...                NaN           NaN
# 2   NaN   NaN   NaN   NaN   NaN     ...                NaN           NaN
# 3   NaN   NaN   NaN   NaN   NaN     ...                NaN           NaN
# 4   NaN   NaN   NaN   NaN   NaN     ...       8.524370e+01  8.364101e+01
#
#            2008          2009          2010          2011          2012  \
# 0  1.742056e+10  1.751630e+10  1.037893e+10  1.213901e+10  1.558436e+10
# 1           NaN  7.574576e+01           NaN           NaN           NaN
# 2           NaN  6.843711e+01           NaN           NaN           NaN
# 3           NaN  7.493961e+01           NaN           NaN           NaN
# 4  7.219425e+01  8.264133e+01  9.212272e+01  7.994722e+01  8.229450e+01
#
#         2013      2014  Unnamed: 43
# 0        NaN       NaN          NaN
# 1        NaN       NaN          NaN
# 2        NaN       NaN          NaN
# 3        NaN       NaN          NaN
# 4  86.973526  88.66328          NaN
#
# [5 rows x 44 columns]

# %%
pd.value_counts(df["Indicator Name"])
# Out:
# GDP expenditure on private consumption (in IDR Million)                                                        546
# Total Specific Allocation Grant for Demographic (in IDR Billion)                                               546
# Education function expenditure (in IDR)                                                                        546
# Number of people employed in agriculture, forestry and fishery                                                 546
# Total Natural Resources Revenue Sharing from Gas (in IDR, realization value)                                   546
# GDP on Mining and Quarrying Sector (in IDR Million), Constant Price                                            546
# Length of District Road: Fair (in km) (Bina Marga Data)                                                        546
# General administration function expenditure (in IDR)                                                           546
# Palm Oil Land Area by type of ownership: Smallholder (in Hectares)                                             546
# Total General Allocation Grant/DAU (in IDR)                                                                    546
# Number of people employed                                                                                      546
# Total Specific Allocation Grant for Infrastructure Sector (Subsect: Water) (in IDR Billion)                    546
# Length of District Road: Bad Damage (in km) (Bina Marga Data)                                                  546
# Total GDP including Oil and Gas (in IDR Million), Constant Price                                               546
# Number of Teacher: Senior Secondary Level (in number of people, 2009 data only)                                546
# Total Credit by Sector: Social Services (province level, in IDR Million)                                       546
# Poverty Line (in IDR)                                                                                          546
# Number of people employed in transportation and telecommunication sector                                       546
# Import: Commodities and transaction not elsewhere classified (province Level, in USD)                          546
# Number of Teacher: Primary Level (in number of people, 2009 data only)                                         546
# Total Natural Resources Revenue Sharing from Oil (in IDR, realization value)                                   546
# Number of people employed in social services sector                                                            546
# Personnel expenditure (in IDR)                                                                                 546
# Total Population for Age 15-64 (only 2005 and 2010) (in number of people)                                      546
# Number of people in labor force                                                                                546
# Length of National Road: Other (in km) (BPS Data, Province only)                                               546
# Length of Province Road: Gravel (in km) (BPS Data, Province only)                                              546
# Health function expenditure (in IDR)                                                                           546
# Villages with road: Asphalt (in % of total villages)                                                           546
# Export: Commodities and transaction not elsewhere classified (province Level, in USD)                          546
#                                                                                                               ...
# Palm Production: Total (in Tons)                                                                               546
# Average National Exam Score: Junior Secondary Level (out of 100, available only in district level for 2009)    546
# GDP on Other Service Sector (in IDR Million), Current Price                                                    546
# Total Specific Allocation Grant for Government Sector (in IDR Billion)                                         546
# Length of Province Road: Light Damage (in km) (BPS Data, Province only)                                        546
# Palm Production by type of ownership: State Owned Enterprise (in Tons)                                         546
# Length of District Road: Dirt (in km) (BPS Data, Province only)                                                546
# Total GDP excluding Oil and Gas (in IDR Million), Current Price                                                546
# Length of District Road: Good (in km) (Bina Marga Data)                                                        546
# Total Specific Allocation Grant for Health (in IDR Billion)                                                    546
# Import: Food and Live Animals (province Level, in USD)                                                         546
# Total Credit by Sector: Other Services (province level, in IDR Million)                                        546
# Palm Oil Yield by type of ownership: State Owned Enterprise (in Kg/Ha)                                         546
# Number of people live below the poverty line (in number of people)                                             546
# Length of Province Road: Dirt (in km) (BPS Data, Province only)                                                546
# Tourism and culture function expenditure (in IDR)                                                              546
# Monthly Per Capita Household Education Expenditure (in IDR)                                                    546
# Total Natural Resources Revenue Sharing from Forestry (in IDR, realization value)                              546
# Total Own Source Revenue/PAD (in IDR)                                                                          546
# Outstanding Deposits of Commercial Banks owned by Regional Government (Province Level, in IDR Million)         546
# Length of National Road: Bad Damage (in km) (BPS Data, Province only)                                          546
# Length of National Road: Dirt (in km) (BPS Data, Province only)                                                546
# Palm Oil Yield by type of ownership: Private (in Kg/Ha)                                                        546
# GDP expenditure on non profit private institution consumption (in IDR Million)                                 546
# Length of National Road: Gravel (in km) (BPS Data, Province only)                                              546
# Housing and public facilities function expenditure (in IDR)                                                    546
# Import: Animals and vegetable oil, fat and waxes (province Level, in USD)                                      546
# Household Access to Safe Water (in % of total household)                                                       546
# Length of District Road: Light Damage (in km) (Bina Marga Data)                                                546
# Total Specific Allocation Grant for Village (in IDR Billion)                                                   546
# Name: Indicator Name, Length: 219, dtype: int64
